# %% [markdown]
# # Intro ASSIGNMENT

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = str(input("What programing language is this ->>>>>>>>>>>>>>>>>>> "))
print(a +" " + "version - " + str(3.12))
# Out:
# python version - 3.12

# %%
a = int(input("enter a num"))
if a>0:
    print(a,"is positive")
elif a==0:
    print(a,"is zero")
elif a<0:
    print(a,"is negative")
# Out:
# -1 is negative

# %%
a = float(input("first "))
b = float(input("second "))
c = float(input("third "))
myset = {a, b, c}

print(myset)

if (a>=b) and (a>+c):
    print("largest :", a)
elif (b>=a) and (b>=c):
    print("largest :", b)
elif (c>=a) and (c>=b):
    print("largest :", c)

## find lagest num of three
# Out:
# {152.2, 152.0, 150.0}
# largest : 152.2

# %%
## factorial of num 
def factorial(n):
    if n == 0:
        return 1
    else :
        return n*factorial(n-1)
    
num = int(input("Enter a num "))
print(f"The factorial of {num} is {factorial(num)}")
# Out:
# The factorial of 7 is 5040

# %%
int_age  = 18
height = 5.5
str_var = "Lakhan-cs"
bool_var = False 


print(f"int value : {int_age}, type: {type(int_age)}")
print(f"float value : {height}, type: {type(height)}")
print(f"str value : {str_var}, type: {type(str_var)}")
print(f"bool value : {bool_var}, type: {type(bool_var)}")
# Out:
# int value : 18, type: <class 'int'>
# float value : 5.5, type: <class 'float'>
# str value : Lakhan-cs, type: <class 'str'>
# bool value : False, type: <class 'bool'>

# %%
## swaping two variable 
a = 10 
b = 20 

print(f"before : a = {a}, b = {b}")  # before swap


a, b = b, a 
print(f"after : a = {a}, b = {b}") # after swap
# Out:
# before : a = 10, b = 20
# after : a = 20, b = 10

# %%
## celsius to fahrenheit convert
celsius = float(input("Enter the celsius "))
fahrenheit = (celsius*9/5) + 32 

print(f"{celsius}C = {fahrenheit}F")
# Out:
# 37.2C = 98.96000000000001F

# %%
a = 5 
b = 20 


print(f"add : {a} + {b} = {a + b}")
print(f"minus : {a} - {b} = {a - b}")
print(f"devide : {a} / {b} = {a / b}")
print(f"multi : {a} * {b} = {a * b}")
# Out:
# add : 5 + 20 = 25
# minus : 5 - 20 = -15
# devide : 5 / 20 = 0.25
# multi : 5 * 20 = 100

# %%
a = 5 
b = 20 


print(f"{a} == {b}: {a==b}")
print(f"{a} != {b}: {a!=b}")
print(f"{a} > {b}: {a>b}")
print(f"{a} < {b}: {a<b}")
# Out:
# 5 == 20: False
# 5 != 20: True
# 5 > 20: False
# 5 < 20: True

# %%
a = True
b = False 

print(f"True and False : {a and b}")
print(f"True or False : {a or b}")
print(f"Not False : { not b}")
# Out:
# True and False : False
# True or False : True
# Not False : True

# %%
num = float(input("Enter a num "))
square = num ** 2
print(f"The square of {num} is {square}")
# Out:
# The square of 15.0 is 225.0

# %%
## FIND ODD EVEN NUM 
num = int(input("Enter a num "))

if num % 2 == 0:
    print(f"{num} is even.")
else :
    print(f"{num} is odd.")
# Out:
# 192 is even.

# %%
## find the sum of n natural num
n = int(input("Enter a num "))

sum_n = (n * (n+1))//2 

print(f"The sum of first {n} natural num is {sum_n}")
# Out:
# The sum of first 10 natural num is 55

# %%
## find a year is leap or not 

year = int(input("Enter a year "))

if (year % 4 == 0 and year % 100 != 0):
    print(f"{year} : it is leap year.")

else : 
    print(f"{year} : it is normal year.")
# Out:
# 2026 : it is normal year.

# %%
## reversed str 
string = input("Enter a str : ")
rev_str = string[::-1]

print(f"The reversed of {string} is {rev_str}")



if string == string[::-1]:
    print(f"{string} is palindrome.")
else : 
    print(f"{string} is not palindrome.")
# Out:
# The reversed of sc-nahkaL is Lakhan-cs
# sc-nahkaL is not palindrome.

# %%
## arrenge list of num in assending order

num = [int(x) for x in input("Enter number separated by space :  ").split()]
num.sort()
print(f"Shorted list: {num}")
# Out:
# Shorted list: [1234]

# %%
# Imp. shortcuts in window 
print(""" win + v  - clipboard his. \n
win + right arrow*2 - two tab in windows \n
win + num(1,2,3..) - open taskbar tab with num \n
win + d - minimise all tab \n
ctrl + backspace - delete a word \n
win + tab - history of windows \n
alt + tab - history \n
shift + home / end - select a sentance \n
win + l - log out from windows \n
ctrl + a - select all \n
ctrl + b - bolding \n
ctrl + c - copy selected \n
ctrl + v - paste copied \n
ctrl + d - delete selected \n
ctrl + h - replace the finding  \n
ctrl + n - new \n
ctrl + s - save \n
ctrl + x - cut \n
ctrl + x +ctrl + v - cut and move (paste copied) \n
ctrl + - -> mini size \n
ctrl + = -> inc. size \n
ctrl + z -> undo \n
ctrl + y -> redo""" )
# Out:
#  win + v  - clipboard his.
#
# win + right arrow*2 - two tab in windows
#
# win + num(1,2,3..) - open taskbar tab with num
#
# win + d - minimise all tab
#
# ctrl + backspace - delete a word
#
# win + tab - history of windows
#
# alt + tab - history
#
# shift + home / end - select a sentance
#
# win + l - log out from windows
#
# ctrl + a - select all
#
# ctrl + b - bolding
#
# ctrl + c - copy selected
#
# ctrl + v - paste copied
#
# ctrl + d - delete selected
#
# ctrl + h - replace the finding
#
# ctrl + n - new
#
# ctrl + s - save
#
# ctrl + x - cut
#
# ctrl + x +ctrl + v - cut and move (paste copied)
#
# ctrl + - -> mini size
#
# ctrl + = -> inc. size
#
# ctrl + z -> undo
#
# ctrl + y -> redo
