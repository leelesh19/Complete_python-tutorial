# %% [markdown]
# ## DATATYPES OF PYTHON

# %%
name = 'lakhan'
print(type(name))
# Out:
# <class 'str'>

# %%
age = 18 
float(age)
# Out:
# 18.0

# %%
print(type(float(age)))
# Out:
# <class 'float'>

# %%
bool(age)
# Out:
# True

# %%
print(type(bool(age)))
# Out:
# <class 'bool'>

# %%
x = 25
y= 25
type(x==y) ##bool gives True and False
# Out:
# bool

# %%
error = "str" + '+' + str(10) 
print(error)
# Out:
# str+10

# %% [markdown]
# ## OPERATORS IN PYTHON

# %%
## arthimetic operators 
a = int(input("value of a "))
b = int(input("value of b"))
print(a - b)
print(a + b)
print(a%b)
print(a/b)
print(a*b)
print(a**b)
print((a*b)/100)
print(a//b)  # here // work as devide but only give ans in int
# Out:
# 2
# 8
# 2
# 1.6666666666666667
# 15
# 125
# 0.15
# 1

# %%
name = 'lakhan'
Name = 'Lakhan'
name != Name
# Out:
# True

# %%
name < Name
# Out:
# False

# %% [markdown]
# # Logical operators and , or ,not

# %%
## and (0, 0, 0, 1)
## or (0, 1, 1, 1)
## not(1, 0)

# %%
x = True 
y = False 

result = x and y 
print(result)
# Out:
# False

# %%
x = True 
y = False 

result = x or y 
print(result)
# Out:
# True

# %%
x = bool(input(" enter a bool value "))

result = not x 
print(result)   ## input ctrl + t
# Out:
# True

# %%
x = False
y = False 

result = x and y 
print(result)
# Out:
# False

# %%
a = False
not a
# Out:
# True
